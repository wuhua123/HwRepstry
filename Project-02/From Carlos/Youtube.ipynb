# %%
#import libraries
#youtube_data has a class 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import seaborn as sns
from youtube_data import youtube_search

# %%
# create a search and loking at object we can work on 
#2018-12-18T18:49:45.000Z - Time format
#bitcoin = youtube_search("Bitcoin", publishedAfter="2018-12-01T00:00:00.000Z", publishedBefore="2018-12-16T00:00:00.000Z")
#bitcoin = youtube_search("Bitcoin", publishedBefore="2018-12-14T04:52:42.000Z")
bitcoin = youtube_search("Bitcoin", publishedAfter="2018-12-16T00:00:00.000Z")
bitcoin.keys()
# Out:
# []
# dict_keys(['tags', 'channelId', 'channelTitle', 'categoryId', 'title', 'videoId', 'viewCount', 'likeCount', 'dislikeCount', 'commentCount', 'favoriteCount', 'publishAt'])

# %%
#Retrieving view count data 
bitcoin['publishAt']

# Save date and time period of data for future use
time_df = pd.DataFrame(bitcoin['publishAt'])
time_df.to_csv("../CSV_Files/bitcoin_youtube_time1_1.csv")

# %%
# dataframe
bitcoin_df = pd.DataFrame(data=bitcoin)
bitcoin_df.head()
# Out:
#                                                 tags  \
# 0  [how to trade bitcoin, is bitcoin dead, will b...
# 1  [bitcoin, Ethereum, investing, crypto lark, xr...
# 2  [Bitcoin crash, bitcoin crash over, is bitcoin...
# 3  [비트코인, 코인, 암호화폐, 차트, 차트분석, 부빗, 트레이딩뷰, 비트, 트뷰, ...
# 4  [bitcoin price, what is the bitcoin price, btc...
#
#                   channelId                                      channelTitle  \
# 0  UCVIOA9XqMtMUk8U-IF-dSYA                                          Forflies
# 1  UCl2oCaw8hdR_kbqyqd2klIA                                   The Crypto Lark
# 2  UCUbgbDVGsgziCGNEKOMBmxQ  TechCashHouse - Best Bitcoin, Crypto, Money News
# 3  UCKEAONWpYx0iUri_-MI1pPg                                   Boo's BITLAB_부빗
# 4  UCFv_fMg2ENc2_6qWmy5I4nQ                                        Mr_Kristof
#
#   categoryId                                              title      videoId  \
# 0         27  BITCOIN LOOKS POISED TO CRASH: HERE'S WHY - BT...  2XZPIBsGHfo
# 1         25  What's Happening to the Price of Bitcoin & Cry...  m9epZwWTzBY
# 2         27  TOM LEE’S MOST RECENT BITCOIN Opinion WILL ABS...  GAQltqKhAUc
# 3         27  [생] 부빗 181220 오후 코인시황, 뉴스점검 / #bitcoin #crypto...  ngOBXdSXlEk
# 4         27  Bitcoin price going to get crushed by the bears?!  0PtWqTEHriY
#
#   viewCount likeCount dislikeCount commentCount favoriteCount  \
# 0      8232       265           55          143             0
# 1      1422       171            2           46             0
# 2       770        74            4           13             0
# 3       232        39            0            0             0
# 4      4093       321            6          206             0
#
#                   publishAt
# 0  2018-12-19T20:48:28.000Z
# 1  2018-12-20T04:18:32.000Z
# 2  2018-12-20T05:00:01.000Z
# 3  2018-12-19T16:44:06.000Z
# 4  2018-12-19T21:50:05.000Z

# %%
# arranging dateframe
bitcoin_arrangeview = bitcoin_df[['title','viewCount','channelTitle','commentCount','likeCount','dislikeCount','tags','favoriteCount','videoId','channelId','categoryId', 'publishAt']]
bitcoin_arrangeview.columns = ['Title','viewCount','channelTitle','commentCount','likeCount','dislikeCount','tags','favoriteCount','videoId','channelId','categoryId', 'publishAt']
bitcoin_arrangeview.head()
# Out:
#                                                Title viewCount  \
# 0  BITCOIN LOOKS POISED TO CRASH: HERE'S WHY - BT...      8232
# 1  What's Happening to the Price of Bitcoin & Cry...      1422
# 2  TOM LEE’S MOST RECENT BITCOIN Opinion WILL ABS...       770
# 3  [생] 부빗 181220 오후 코인시황, 뉴스점검 / #bitcoin #crypto...       232
# 4  Bitcoin price going to get crushed by the bears?!      4093
#
#                                        channelTitle commentCount likeCount  \
# 0                                          Forflies          143       265
# 1                                   The Crypto Lark           46       171
# 2  TechCashHouse - Best Bitcoin, Crypto, Money News           13        74
# 3                                   Boo's BITLAB_부빗            0        39
# 4                                        Mr_Kristof          206       321
#
#   dislikeCount                                               tags  \
# 0           55  [how to trade bitcoin, is bitcoin dead, will b...
# 1            2  [bitcoin, Ethereum, investing, crypto lark, xr...
# 2            4  [Bitcoin crash, bitcoin crash over, is bitcoin...
# 3            0  [비트코인, 코인, 암호화폐, 차트, 차트분석, 부빗, 트레이딩뷰, 비트, 트뷰, ...
# 4            6  [bitcoin price, what is the bitcoin price, btc...
#
#   favoriteCount      videoId                 channelId categoryId  \
# 0             0  2XZPIBsGHfo  UCVIOA9XqMtMUk8U-IF-dSYA         27
# 1             0  m9epZwWTzBY  UCl2oCaw8hdR_kbqyqd2klIA         25
# 2             0  GAQltqKhAUc  UCUbgbDVGsgziCGNEKOMBmxQ         27
# 3             0  ngOBXdSXlEk  UCKEAONWpYx0iUri_-MI1pPg         27
# 4             0  0PtWqTEHriY  UCFv_fMg2ENc2_6qWmy5I4nQ         27
#
#                   publishAt
# 0  2018-12-19T20:48:28.000Z
# 1  2018-12-20T04:18:32.000Z
# 2  2018-12-20T05:00:01.000Z
# 3  2018-12-19T16:44:06.000Z
# 4  2018-12-19T21:50:05.000Z

# %%
#kickoff = [item.replace("'", "") for item in kickoff]
#for i in range(len(bitcoin_arrangeview['commentCount'])):
    #bitcoin_arrangeview.loc[i, 'commentCount'] = bitcoin_arrangeview.loc[i, 'commentCount'].replace('[]', '0') for item in bitcoin_arrangeview['commentCount']
#bitcoin_arrangeview.commentCount.replace('[]', 0)
#bitcoin_arrangeview['commentCount'] = bitcoin_arrangeview.commentCount.replace('[]', '0')
#print(bitcoin_arrangeview['commentCount'])

# %%
# Selecting the rows to convert into intergers from strings
numeric_dtype = ['viewCount','likeCount','dislikeCount','favoriteCount']

# %%
# loop to integers
for i in numeric_dtype:
        bitcoin_arrangeview[i] = bitcoin_df[i].astype(int)

# %%
new_topics_data_df = bitcoin_arrangeview[['channelTitle', 'Title', 'viewCount', 'likeCount', 'publishAt']]
new_topics_data_df.head(25)
# Out:
#                                         channelTitle  \
# 0                                           Forflies
# 1                                    The Crypto Lark
# 2   TechCashHouse - Best Bitcoin, Crypto, Money News
# 3                                    Boo's BITLAB_부빗
# 4                                         Mr_Kristof
# 5                                       sunny decree
# 6                                    Alessio Rastani
# 7                      Bloomberg Markets and Finance
# 8                         Learn Crypto / Wyckoff SMI
# 9                                       Crypto Daily
# 10                              Bitcoin-Fund-Manager
# 11                                      Peter Schiff
# 12                                The Crypto Analyst
# 13                                      Crypto Daily
# 14                                     Kevin Svenson
# 15                     Bloomberg Markets and Finance
# 16                                     Crypto Zombie
# 17  TechCashHouse - Best Bitcoin, Crypto, Money News
# 18                              Bitcoin-Fund-Manager
# 19                                     Altcoin Daily
# 20                               The Modern Investor
# 21                                   Money Authority
# 22                                   CNBC Television
# 23                                   CNBC Television
# 24                                      Fox Business
#
#                                                 Title  viewCount  likeCount  \
# 0   BITCOIN LOOKS POISED TO CRASH: HERE'S WHY - BT...       8232        265
# 1   What's Happening to the Price of Bitcoin & Cry...       1422        171
# 2   TOM LEE’S MOST RECENT BITCOIN Opinion WILL ABS...        770         74
# 3   [생] 부빗 181220 오후 코인시황, 뉴스점검 / #bitcoin #crypto...        232         39
# 4   Bitcoin price going to get crushed by the bears?!       4093        321
# 5          Bitcoin Top Shorter closed his Position!!!      19838       1103
# 6   Will Bitcoin's Bounce Gather Momentum or Run O...      24452       1789
# 7   Will Bitcoin Rebound in 2019? The Bull vs. Bea...      48798        818
# 8   Bitcoin ABC Correction? Institutions Bailing? ...        691         55
# 9         We're Being Manipulated - The Bitcoin Price      26446       3489
# 10    BITCOIN DEAD UNLESS INSTITUTIONAL FIAT ONRAMPS!        466         58
# 11                      🔴 Bitcoin is Not a Safe Haven      18077        640
# 12  BITCOIN: How Far Can It Go? BTC Technical Anal...        338         37
# 13                     Start Of The Bitcoin Bull Run?      31647       3185
# 14  Bitcoin | Continued Push↗🔴 LIVE ❄ Crypto Winter ❄       4574        314
# 15  Novogratz Sees Bitcoin at $3,000 to $6,000 in ...       6037         82
# 16  BITCOIN Santa Claus RALLY?!? 🚀 Crypto Trader W...      11154        683
# 17  BUYING BITCOIN RIGHT NOW May Be THE BEST DECIS...       3121        176
# 18  URGENT BITCOIN UPDATE: SKYROCKET. FED INTEREST...      49006       1569
# 19  Bitcoin Price Jumps 10% and is STILL Climbing!...      15880        625
# 20  Bitcoin In China, Ethereum PoS, Bitcoin Lighti...      12235        589
# 21  Bitcoin & Crypto Markets Break Out Again! Here...       2977        100
# 22  It's been a year since bitcoin hit all-time hi...      12865        148
# 23  We're getting closer to the bitcoin bottom, sa...      10672         81
# 24  Bitcoin surges one year after hitting all-time...       2812         48
#
#                    publishAt
# 0   2018-12-19T20:48:28.000Z
# 1   2018-12-20T04:18:32.000Z
# 2   2018-12-20T05:00:01.000Z
# 3   2018-12-19T16:44:06.000Z
# 4   2018-12-19T21:50:05.000Z
# 5   2018-12-19T05:44:47.000Z
# 6   2018-12-19T19:31:01.000Z
# 7   2018-12-17T18:28:32.000Z
# 8   2018-12-20T02:35:55.000Z
# 9   2018-12-19T19:43:06.000Z
# 10  2018-12-20T06:07:38.000Z
# 11  2018-12-18T20:33:39.000Z
# 12  2018-12-19T19:22:38.000Z
# 13  2018-12-18T16:34:52.000Z
# 14  2018-12-19T05:38:43.000Z
# 15  2018-12-18T18:49:45.000Z
# 16  2018-12-19T16:22:56.000Z
# 17  2018-12-19T05:00:03.000Z
# 18  2018-12-18T09:36:02.000Z
# 19  2018-12-19T11:30:00.000Z
# 20  2018-12-19T10:53:36.000Z
# 21  2018-12-19T01:34:57.000Z
# 22  2018-12-17T23:29:30.000Z
# 23  2018-12-17T19:49:28.000Z
# 24  2018-12-17T22:07:13.000Z

# %%
#sort by view count
new_topics_data_df.sort_values(["viewCount"], ascending=False)
# Out:
#                                         channelTitle  \
# 18                              Bitcoin-Fund-Manager
# 7                      Bloomberg Markets and Finance
# 34                                           Timcast
# 46                                      Crypto Daily
# 45                                  CANAL DO BITCOIN
# 13                                      Crypto Daily
# 9                                       Crypto Daily
# 30                                     Altcoin Daily
# 6                                    Alessio Rastani
# 42                              Crypto Kirby Trading
# 5                                       sunny decree
# 43                                          The Moon
# 11                                      Peter Schiff
# 36                                         Tone Vays
# 19                                     Altcoin Daily
# 28                                   Dr. Julian Hosp
# 39                                      Ivan on Tech
# 22                                   CNBC Television
# 35  TechCashHouse - Best Bitcoin, Crypto, Money News
# 26  TechCashHouse - Best Bitcoin, Crypto, Money News
# 20                               The Modern Investor
# 16                                     Crypto Zombie
# 23                                   CNBC Television
# 25                                      Trevon James
# 0                                           Forflies
# 49                                       Crypto Crow
# 15                     Bloomberg Markets and Finance
# 29                                        Crypto AMD
# 48                                   The Crypto Lark
# 37                            Crypto Capital Venture
# 14                                     Kevin Svenson
# 4                                         Mr_Kristof
# 41                                        Mr_Kristof
# 44                                    Fausto Botelho
# 32  TechCashHouse - Best Bitcoin, Crypto, Money News
# 47                               Человек из будущего
# 17  TechCashHouse - Best Bitcoin, Crypto, Money News
# 31                                         Mitch Ray
# 21                                   Money Authority
# 24                                      Fox Business
# 33         Finanzielle Freiheit dank Kryptowährungen
# 38                                     Kripto Sözlük
# 40                                           BTCKYLE
# 1                                    The Crypto Lark
# 2   TechCashHouse - Best Bitcoin, Crypto, Money News
# 8                         Learn Crypto / Wyckoff SMI
# 10                              Bitcoin-Fund-Manager
# 27                                      Ivan on Tech
# 12                                The Crypto Analyst
# 3                                    Boo's BITLAB_부빗
#
#                                                 Title  viewCount  likeCount  \
# 18  URGENT BITCOIN UPDATE: SKYROCKET. FED INTEREST...      49006       1569
# 7   Will Bitcoin Rebound in 2019? The Bull vs. Bea...      48798        818
# 34  Dave Rubin Adds Bitcoin, Crypto Can SAVE Free ...      40349       2722
# 46  Bitcoin Holders MUST Understand This - Perspec...      36331       3234
# 45                                 Análise do Bitcoin      33112        479
# 13                     Start Of The Bitcoin Bull Run?      31647       3185
# 9         We're Being Manipulated - The Bitcoin Price      26446       3489
# 30  Bakkt Reveals Potential Bitcoin and Crypto Par...      24965       1248
# 6   Will Bitcoin's Bounce Gather Momentum or Run O...      24452       1789
# 42  Bitcoin (BTC) is PUMPING! How High Can It Go?!...      23518       1135
# 5          Bitcoin Top Shorter closed his Position!!!      19838       1103
# 43  BITCOIN BREAKING OUT!!! | Wedge Target Is $4,4...      19098       1150
# 11                      🔴 Bitcoin is Not a Safe Haven      18077        640
# 36  Bitcoin Brief - 1yr from ATH, Blockstream Sate...      15943        538
# 19  Bitcoin Price Jumps 10% and is STILL Climbing!...      15880        625
# 28  Ist Bitcoin nun tot weil Mining Difficulty run...      15643       1198
# 39    Who Controls Bitcoin Core? Programmer explains.      13774        981
# 22  It's been a year since bitcoin hit all-time hi...      12865        148
# 35  JOHN MCAFEE DOUBLES DOWN On BULLISH BITCOIN Pr...      12779        267
# 26  JOHN MCAFEE’S AMAZING New BITCOIN FACTS Will B...      12743        541
# 20  Bitcoin In China, Ethereum PoS, Bitcoin Lighti...      12235        589
# 16  BITCOIN Santa Claus RALLY?!? 🚀 Crypto Trader W...      11154        683
# 23  We're getting closer to the bitcoin bottom, sa...      10672         81
# 25                       LAST CHANCE TO SELL BITCOIN?       9179        513
# 0   BITCOIN LOOKS POISED TO CRASH: HERE'S WHY - BT...       8232        265
# 49  YOU'VE BEEN DUPED - The Wealthy vs Dumb Money ...       6121        418
# 15  Novogratz Sees Bitcoin at $3,000 to $6,000 in ...       6037         82
# 29  Bitcoin Price Technical Analysis December 18 2018       5142        293
# 48       Bitcoin & Crypto Price News - Is There Hope?       5046        462
# 37                Bitcoin Price Trend - $90k in 2021?       4921        278
# 14  Bitcoin | Continued Push↗🔴 LIVE ❄ Crypto Winter ❄       4574        314
# 4   Bitcoin price going to get crushed by the bears?!       4093        321
# 41  Is this the Bitcoin bounce we have been waitin...       3990        264
# 44                         BITCOIN REVERTED - SEE WHY       3869        389
# 32  What Do DONALD TRUMP & THIS MAN Know ABOUT BIT...       3497        175
# 47  ПРЕДСКАЗАЛ ПАДЕНИЕ BITCOIN И ЦЕЛЫЙ ГОД НА ЭТОМ...       3337        233
# 17  BUYING BITCOIN RIGHT NOW May Be THE BEST DECIS...       3121        176
# 31  Bitcoin : Attempting a Rally. TRX Pumping! Epi...       3120        480
# 21  Bitcoin & Crypto Markets Break Out Again! Here...       2977        100
# 24  Bitcoin surges one year after hitting all-time...       2812         48
# 33  BITCOIN AUF 1 MILLION DOLLAR & DANACH AUF 100K...       2579        368
# 38  DİKKAT! BITCOIN NEDEN YÜKSELİYOR? (BTC ve Altc...       2512        318
# 40                       Bitcoin Bounced -- Now What?       1976        145
# 1   What's Happening to the Price of Bitcoin & Cry...       1422        171
# 2   TOM LEE’S MOST RECENT BITCOIN Opinion WILL ABS...        770         74
# 8   Bitcoin ABC Correction? Institutions Bailing? ...        691         55
# 10    BITCOIN DEAD UNLESS INSTITUTIONAL FIAT ONRAMPS!        466         58
# 27       BITCOIN BULL MATH - Shorting and Percentages        347         36
# 12  BITCOIN: How Far Can It Go? BTC Technical Anal...        338         37
# 3   [생] 부빗 181220 오후 코인시황, 뉴스점검 / #bitcoin #crypto...        232         39
#
#                    publishAt
# 18  2018-12-18T09:36:02.000Z
# 7   2018-12-17T18:28:32.000Z
# 34  2018-12-18T23:30:00.000Z
# 46  2018-12-17T20:57:03.000Z
# 45  2018-12-18T11:32:37.000Z
# 13  2018-12-18T16:34:52.000Z
# 9   2018-12-19T19:43:06.000Z
# 30  2018-12-17T12:00:06.000Z
# 6   2018-12-19T19:31:01.000Z
# 42  2018-12-18T06:34:06.000Z
# 5   2018-12-19T05:44:47.000Z
# 43  2018-12-18T11:03:43.000Z
# 11  2018-12-18T20:33:39.000Z
# 36  2018-12-18T18:00:32.000Z
# 19  2018-12-19T11:30:00.000Z
# 28  2018-12-18T09:17:14.000Z
# 39  2018-12-17T08:08:00.000Z
# 22  2018-12-17T23:29:30.000Z
# 35  2018-12-17T00:00:01.000Z
# 26  2018-12-18T05:00:02.000Z
# 20  2018-12-19T10:53:36.000Z
# 16  2018-12-19T16:22:56.000Z
# 23  2018-12-17T19:49:28.000Z
# 25  2018-12-17T16:28:12.000Z
# 0   2018-12-19T20:48:28.000Z
# 49  2018-12-18T20:50:27.000Z
# 15  2018-12-18T18:49:45.000Z
# 29  2018-12-18T20:11:07.000Z
# 48  2018-12-18T03:51:38.000Z
# 37  2018-12-19T01:58:17.000Z
# 14  2018-12-19T05:38:43.000Z
# 4   2018-12-19T21:50:05.000Z
# 41  2018-12-18T22:36:31.000Z
# 44  2018-12-18T22:42:22.000Z
# 32  2018-12-18T00:00:02.000Z
# 47  2018-12-19T16:04:37.000Z
# 17  2018-12-19T05:00:03.000Z
# 31  2018-12-19T06:53:39.000Z
# 21  2018-12-19T01:34:57.000Z
# 24  2018-12-17T22:07:13.000Z
# 33  2018-12-19T15:15:14.000Z
# 38  2018-12-19T16:00:01.000Z
# 40  2018-12-17T22:42:45.000Z
# 1   2018-12-20T04:18:32.000Z
# 2   2018-12-20T05:00:01.000Z
# 8   2018-12-20T02:35:55.000Z
# 10  2018-12-20T06:07:38.000Z
# 27  2018-12-20T07:00:01.000Z
# 12  2018-12-19T19:22:38.000Z
# 3   2018-12-19T16:44:06.000Z

# %%
# Add one column source to indicate the data source
new_topics_data_df['source'] = 'Youtube'

print(new_topics_data_df.dtypes)
print(new_topics_data_df.head())
# Out:
# channelTitle    object
# Title           object
# viewCount        int32
# likeCount        int32
# publishAt       object
# source          object
# dtype: object
#                                        channelTitle  \
# 0                                          Forflies
# 1                                   The Crypto Lark
# 2  TechCashHouse - Best Bitcoin, Crypto, Money News
# 3                                   Boo's BITLAB_부빗
# 4                                        Mr_Kristof
#
#                                                Title  viewCount  likeCount  \
# 0  BITCOIN LOOKS POISED TO CRASH: HERE'S WHY - BT...       8232        265
# 1  What's Happening to the Price of Bitcoin & Cry...       1422        171
# 2  TOM LEE’S MOST RECENT BITCOIN Opinion WILL ABS...        770         74
# 3  [생] 부빗 181220 오후 코인시황, 뉴스점검 / #bitcoin #crypto...        232         39
# 4  Bitcoin price going to get crushed by the bears?!       4093        321
#
#                   publishAt   source
# 0  2018-12-19T20:48:28.000Z  Youtube
# 1  2018-12-20T04:18:32.000Z  Youtube
# 2  2018-12-20T05:00:01.000Z  Youtube
# 3  2018-12-19T16:44:06.000Z  Youtube
# 4  2018-12-19T21:50:05.000Z  Youtube
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_topics_data_df.to_csv("../CSV_Files/bitcoin_youtube3.csv", header=True)

# %%
# Strip off time part of datetime:
new_topics_data_df['publishAt'] = pd.to_datetime(new_topics_data_df['publishAt'])

for i in range(len(new_topics_data_df['publishAt'])):
    new_topics_data_df.loc[i, 'publishAt'] = new_topics_data_df.loc[i, 'publishAt'].date()
    
#print(new_topics_data_df['publishAt'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
# Convert datatime64 to string for column created:
new_topics_data_df['publishAt'] = new_topics_data_df['publishAt'].astype(str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Convert pd int64 into int32 for column retweet and favorite_count:
# channelTitle	Title	viewCount	likeCount	publishAt
new_topics_data_df['viewCount'] = pd.Series(new_topics_data_df['viewCount'], dtype=str)
new_topics_data_df['likeCount'] = pd.Series(new_topics_data_df['likeCount'], dtype=str)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# Replace NaN with None
new_topics_data_df = new_topics_data_df.where(pd.notnull(new_topics_data_df), None)

# %%
# Check data types    
new_topics_data_df.dtypes
# Out:
# channelTitle    object
# Title           object
# viewCount       object
# likeCount       object
# publishAt       object
# source          object
# dtype: object

# %%
# Dependencies
# ----------------------------------

from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import Column, Integer, String, Float, UnicodeText, Date, BigInteger

Base = declarative_base()

# %%
# Create Bitcoin_Youtube Classe: channelTitle	Title	viewCount	likeCount	publishAt
# ----------------------------------


class Bitcoin_Youtube(Base):
    __tablename__ = 'bitcoin_youtube'
    id = Column(Integer, primary_key=True)
    channelTitle = Column(String(200))
    Title = Column(UnicodeText)
    viewCount = Column(Integer)
    likeCount = Column(Integer)
    publishAt = Column(Date)
    source = Column(String(20))

# %%
# Create Database Connection
# ----------------------------------
# PyMySQL 
import pymysql
pymysql.install_as_MySQLdb()

#engine = create_engine("mysql://k5xunpkmojyzse51:ifagg1gp7e2xyapi@ffn96u87j5ogvehy.cbetxkdyhwsb.us-east-1.rds.amazonaws.com:3306/tq6h098h0ym00zp6")
engine = create_engine("mysql://root:Winter#1@127.0.0.1:3306/crypto_db")
conn = engine.connect()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py:170: Warning: (3719, "'utf8' is currently an alias for the character set UTF8MB3, but will be an alias for UTF8MB4 in a future release. Please consider using UTF8MB4 in order to be unambiguous.")
#   result = self._query(query)

# %%
# Create a "Metadata" Layer That Abstracts our SQL Database
# ----------------------------------
# Create (if not already in existence) the tables associated with our classes.
Base.metadata.create_all(engine)

# Use this to clear out the db
# ----------------------------------
# Base.metadata.drop_all(engine)

# %%
# Create a Session Object to Connect to DB
# ----------------------------------
from sqlalchemy.orm import Session
session = Session(bind=engine)

# %%
# Add Records to the Appropriate DB
# ----------------------------------
# Use the SQL ALchemy methods to run simple "INSERT" statements using the class and object of Bitcoin_Youtube.
# channelTitle	Title	viewCount	likeCount	publishAt

for i in range(len(new_topics_data_df['publishAt'])):  
    one_bitcoin_youtube = Bitcoin_Youtube(channelTitle=new_topics_data_df.loc[i,'channelTitle'],
                                          Title=new_topics_data_df.loc[i,'Title'],
                                          viewCount=new_topics_data_df.loc[i,'viewCount'],
                                          likeCount=new_topics_data_df.loc[i,'likeCount'],
                                          publishAt=new_topics_data_df.loc[i,'publishAt'],
                                          source=new_topics_data_df.loc[i,'source'])
    session.add(one_bitcoin_youtube)
    session.commit()
