# %%
import re 
import tweepy 
from tweepy import OAuthHandler 
from textblob import TextBlob

#config
from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
class TwitterClient(object): 
    ''' 
    Generic Twitter Class for sentiment analysis. 
    '''
    def __init__(self): 
        ''' 
        Class constructor or initialization method. 
        '''
  
        # attempt authentication 
        try: 
            # create OAuthHandler object 
            self.auth = OAuthHandler(consumer_key, consumer_secret) 
            # set access token and secret 
            self.auth.set_access_token(access_token, access_token_secret) 
            # create tweepy API object to fetch tweets 
            self.api = tweepy.API(self.auth) 
        except: 
            print("Error: Authentication Failed") 
  
    def clean_tweet(self, tweet): 
        ''' 
        Utility function to clean tweet text by removing links, special characters 
        using simple regex statements. 
        '''
        return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split()) 
  
    def get_tweet_sentiment(self, tweet): 
        ''' 
        Utility function to classify sentiment of passed tweet 
        using textblob's sentiment method 
        '''
        # create TextBlob object of passed tweet text 
        analysis = TextBlob(self.clean_tweet(tweet)) 
        # set sentiment 
        if analysis.sentiment.polarity > 0: 
            return 'positive'
        elif analysis.sentiment.polarity == 0: 
            return 'neutral'
        else: 
            return 'negative'
  
    def get_tweets(self, query, count = 10): 
        ''' 
        Main function to fetch tweets and parse them. 
        '''
        # empty list to store parsed tweets 
        tweets = [] 
  
        try: 
            # call twitter api to fetch tweets 
            fetched_tweets = self.api.search( q = query, count = count) 
  
            # parsing tweets one by one 
            for tweet in fetched_tweets: 
                # empty dictionary to store required params of a tweet 
                parsed_tweet = {} 
  
                # saving text of tweet 
                parsed_tweet['text'] = tweet.text 
                # saving sentiment of tweet 
                parsed_tweet['sentiment'] = self.get_tweet_sentiment(tweet.text) 
  
                # appending parsed tweet to tweets list 
                if tweet.retweet_count > 0: 
                    # if tweet has retweets, ensure that it is appended only once 
                    if parsed_tweet not in tweets: 
                        tweets.append(parsed_tweet) 
                else: 
                    tweets.append(parsed_tweet) 
  
            # return parsed tweets 
            return tweets 
  
        except tweepy.TweepError as e: 
            # print error (if any) 
            print("Error : " + str(e)) 
  
def main(): 
    # creating object of TwitterClient Class 
    api = TwitterClient() 
    # calling function to get tweets 
    tweets = api.get_tweets(query = 'Bitcoin', count = 200) 
  
    # picking positive tweets from tweets 
    ptweets = [tweet for tweet in tweets if tweet['sentiment'] == 'positive'] 
    # percentage of positive tweets 
    print("Positive tweets percentage: {} %".format(100*len(ptweets)/len(tweets))) 
    # picking negative tweets from tweets 
    ntweets = [tweet for tweet in tweets if tweet['sentiment'] == 'negative'] 
    # percentage of negative tweets 
    print("Negative tweets percentage: {} %".format(100*len(ntweets)/len(tweets))) 
    # percentage of neutral tweets 
    print("Neutral tweets percentage: {} %".format(100*(len(tweets)-len(ntweets) - len(ptweets))/len(tweets))) 
  
    # printing first 5 positive tweets 
    print("\n\nPositive tweets:") 
    for tweet in ptweets[:10]: 
        print(tweet['text']) 
  
    # printing first 5 negative tweets 
    print("\n\nNegative tweets:") 
    for tweet in ntweets[:10]: 
        print(tweet['text']) 
  
if __name__ == "__main__": 
    # calling main function 
    main()
# Out:
# Positive tweets percentage: 37.333333333333336 %
# Negative tweets percentage: 13.333333333333334 %
# Neutral tweets percentage: 49.333333333333336 %
#
#
# Positive tweets:
# RT @HubrisOne: @HubrisOne Alpha App is now live on Google Play store and Apple store (in 24 hours). Register and receive $10 in HBRS tokens…
# RT @localtradepro: Candidate Receives First Ever Bitcoin Donation to a Political Campaign in Taiwan https://t.co/dt8aXLWPxz https://t.co/5k…
# RT @griffexco: You’d be making a mistake, if you are dismissing this fact, cause its against the popular belief. Its not just a coincidence…
# RT @CoinAirdropsAll: #Bitcoin #cryptocurrency #Airdrop
# New Airdrop #ETHX 📢
#
# Earn Up to 2500 #ETHX (~$500)
#
# ETHX is airdropping #ETHX Tokens…
# RT @Airdropnotecom: #Bitcoin #Satoshi #crypto #blockchain #Airdrop
# New Airdrop #Griffex 📢
#
# Griffex is airdropping up to 9400 #GFX to their…
# i really dont want to have my precious Bitcoin confronted with to many apps, i want user doing their business with… https://t.co/7pjGzsOAxl
# Nothing can increase by that much and still be a good investment.
#
# 👉 https://t.co/Plcaxoa43K 👀
#
# Register Now &amp; Star… https://t.co/IC1BOHNBSX
# RT @_blockandchain_: Chinese 24 year old Bitcoin Millionaire Wong ching kit 黄鉦杰 AKA bi shao ye 币少爷 (Mr coin ) throws 100’s of millions of H…
# New post: わい、ついにリップルに手を出すwwwwww　　　　　　#仮想通貨　$XRP1: 以下、5ちゃんねるからVIPがお送りします  2018 https://t.co/qX2nrBCYWN
# RT @rektcapital: Check out my new blog post:
# "Bitcoin's Market Cycles - Everything You Need to Know."
#
# https://t.co/ouimMBiVN0
#
# $crypto $B…
#
#
# Negative tweets:
# RT @MebFaber: Summary of asset class returns in 2018:
#
# US Large Cap: Down
# US Small Cap: Down
# Foreign Developed: Down
# Foreign Emerging: Down…
# RT @kashthefuturist: #AugmentedReality Pong Game
#
# #AI #IoT #digital #Robotics #Robot #DigitalTransformation #future #technology #TechTrends…
# RT @CalvinAyre: #BSV is now officially boringly stable (other than the necessary massive scaling) and we will make it simple.....these guys…
# RT @nocoinerclub: Looks like Gab is heading down the wormhole.. and bringing a million people with them.
# #bitcoin https://t.co/Xwb3R3xlkx
# RT @lopp: It's time to put another endless debate to rest. https://t.co/1Uqbu9wzB5
# RT @Airdropnotecom: #Bitcoin #crypto #Airdrop
# New Airdrop #Cryptosoul 📢
#
# CryptoSoul is the first battle royale mining game in the world ✈️💰…
# @DZack23 If a guy pretending to be half Elon Musk and half Giancarlo Devasini can't save Bitcoin and Tether - then who can?
# Bitcoin will SOAR: Market is WRONG about cryptocurrency – Thomas Lee predicts RISE https://t.co/sbJ4GwlSGT https://t.co/da1JQbzdgz
# RT @MiguelCuneta: I can't imagine how frustrating it is for critics of #Bitcoin to keep attacking something that doesn't give a literal shi…
# RT @RobertBeadles: 3.2 Million Dollar Bitcoin? Here in this quick and dirty little ramble, I address the most common crypto questions. Thes…

# %%
help(tweepy.api.search)
# Out:
# Help on function _call in module tweepy.binder:
#
# _call(*args, **kwargs)
